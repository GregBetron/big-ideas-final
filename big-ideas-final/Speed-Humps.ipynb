# %% [markdown]
# ### Atara Montaque's Findings

# %% [markdown]
# Introduction

# %% [markdown]
# In this analysis, I will focus on the speed humps installed by the City of Pittsburgh as an indicator of neighborhood quality. Speed humps serve as traffic calming measures, enhancing safety and promoting a pedestrian-friendly environment. More speed humps in a neighborhood can lead to reduced speeding and traffic noise, potentially improving residents' quality of life. The dataset provides detailed information on the location and quantity of speed humps in each neighborhood.

# %% [markdown]
# Metric

# %% [markdown]
# The metric used to evaluate neighborhood quality is the number of speed humps installed. This metric reflects the city's efforts to implement traffic calming measures, contributing to safer streets and enhanced livability. By comparing the quantity of speed humps across neighborhoods, we can identify areas that prioritize traffic safety and potentially offer a higher quality of life for residents.

# %%
# First Import Pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('Speed_Humps.csv')

# Group the data by neighborhood and count the number of speed humps in each neighborhood
neighborhood_speed_humps = df.groupby('neighborhood')['hump_id'].count().reset_index()

# Rename the column for clarity
neighborhood_speed_humps.columns = ['Neighborhood', 'Number_of_Speed_Humps']

# Print the DataFrame results
print(neighborhood_speed_humps)
# Out:
#            Neighborhood  Number_of_Speed_Humps
# 0            Bloomfield                      3
# 1             Brookline                      4
# 2               Carrick                      9
# 3       Central Oakland                      1
# 4              Garfield                      3
# 5         Highland Park                      2
# 6        Homewood South                      4
# 7      Mount Washington                      3
# 8         North Oakland                      6
# 9             Overbrook                      1
# 10          Perry North                      4
# 11          Polish Hill                      6
# 12     South Side Flats                      3
# 13    South Side Slopes                      4
# 14  Squirrel Hill North                      3
# 15  Squirrel Hill South                     18
# 16      Stanton Heights                      1
# 17           Upper Hill                      4

# %%
# Use a bar chart to visualize the number of speed humps in each neighborhood
plt.figure(figsize=(12, 6))
plt.bar(neighborhood_speed_humps['Neighborhood'], neighborhood_speed_humps['Number_of_Speed_Humps'])
plt.xlabel('Neighborhood')
plt.ylabel('Number of Speed Humps')
plt.title('Number of Speed Humps in Each Neighborhood')
plt.xticks(rotation=90)
plt.ylim(0, 18) # Set the y-axis limits
plt.show()

# %% [markdown]
# ### Best Neighborhood
#  According to the data, Squirrel Hill South stands out as the neighborhood with the most speed humps, totaling 18.
# This indicates a strong focus on traffic safety and likely contributes to a better living environment for the people there.
# The presence of more speed humps suggests that the neighborhood prioritizes pedestrian safety and may have lower levels of speeding vehicles, making it a potentially safer and more pleasant place to live.
